# %%
import cfl

# %%
cfl.authenticate("<API_KEY>")

# %%
cfl.get_available_dataset_ids()

# %%
cfl.opsd.get_description()

# %%
cfl.opsd.get_household_data(temporal_resolution="60min")

# %%
cfl.opsd.get_household_data(temporal_resolution="15min")

# %%
cfl.opsd.get_household_data(temporal_resolution="1min")

# %%
cfl.wpuq.get_description()

# %%
cfl.wpuq.get_weather_data(year=2018)

# %%
cfl.wpuq.get_weather_data(year=2019)

# %%
cfl.wpuq.get_weather_data(year=2020)

# %%
cfl.wpuq.get_heatpump_load_data(temporal_resolution='1min', year=2018, only_no_pv=True)

# %%
cfl.wpuq.get_heatpump_load_data(temporal_resolution='15min', year=2019, only_pv=True)

# %%
cfl.wpuq.get_household_load_data(temporal_resolution='15min', year=2019)

# %%
cfl.wpuq.get_household_load_data(temporal_resolution='60min', year=2020)

# %%
cfl.wpuq.get_district_heating_grid_data(year=2018)

# %%
cfl.wpuq.get_misc_data(year=2019, temporal_resolution='60min')

# %%
cfl.deddiag.get_description()

# %%
cfl.deddiag.get_house_description(house_id=8)

# %%
cfl.deddiag.get_item_data(house_id=10)

# %%
cfl.deddiag.get_item_annotations(house_id=0)

# %%
cfl.deddiag.get_item_descriptions(house_id=4)
