# %%
import emtl

# %%
emtl.authenticate("<todo_secret>")  # todo

# %%
emtl.get_available_dataset_ids()
# Out:
# ⠹ Data server: Collecting and preparing data...
# ['dummy_dataset', 'eye2sky', 'wpuq']

# %%
print(emtl.get_wpuq_description())
# Out:
# WPuQ dataset:
# This is a test dataset for testing the EMT dataloader.
# Electric load of 38 households measured in a small village in Lower Saxony, Germany.
# Data is available for voltage, reactive power and active power.
# Separate measurements are available for each total household load, for each heat pump and at the local power transformer.
# Different temporal and spatial aggregations are available for convenience.
#
# Authors: Schlemminger, Marlon; Ohrdes, Tobias; Schneider, Elisabeth; Knoop, Michael
# Paper: https://www.nature.com/articles/s41597-022-01156-1
# Raw data: https://zenodo.org/records/5642902
#
# Request logic:
# - For each year (2018–2020), multiple hdf5 files exist that contain the data tables (see original paper).
# - The WPuQ hdf5 files organize data tables in a three-level tree structure.
# - Each request specifies the top, mid, and low-level nodes for which data should be retrieved.
# ...

# %%
df = emtl.get_wpuq_household_load_data(
    year=2020,  
    temporal_resolution="15min"
)
df
# Out:
# ⠋ Data server: Collecting and preparing data...
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 df = emtl.get_wpuq_household_load_data(
#       2     year=2020,
#       3     temporal_resolution="15min"
#       4 )
#       5 df
#
# File ~/Documents/EMT/dataloader/data-loader/data_loader/src/emtl/custom_data_getters/wpuq.py:53, in get_wpuq_household_load_data(year, temporal_resolution, only_pv, only_no_pv, cache)
#      24 def get_wpuq_household_load_data(year: int, temporal_resolution: str,
#      25                                  only_pv: bool = False, only_no_pv: bool = False,
#      26                                  cache: bool = True) -> pd.DataFrame:
#      27     """
#      28     Retrieve WPuQ household electricity load data.
#      29
#    (...)     51
#      52     """
# ...

# %%
emtl.clear_cache()
