# %%
import cfl

# %%
# TODO -> FastAPI cf_server must be running -> see README.MD -> 'Testing Server Locally'
cfl.set_host("http://127.0.0.1:8000")

# TODO -> create a dummy_api_key following the procedure described in /data_server/src/cf_server/auth/api_key_management.py
cfl.authenticate("<API_KEY>")

# %%
cfl.get_available_dataset_ids()
# Out:
# ['deddiag', 'dummy_dataset', 'opsd', 'wpuq']

# %%
cfl.get_request_schema('dummy_dataset')
# Out:
# ⠦ Data server: Collecting and preparing data...
# {'dataset_id': 'dummy_dataset',
#  'description': "This dataset is intended for testing the common-fetch data loader. \nThe only mandatory parameter is 'year', which determines the dataset to be loaded. \n",
#  'request_logic': 'Test data is available for 2024 and 2025.\n',
#  'request': {'year': 2025}}

# %%
cfl.dummy_dataset.get_description()
# Out:
# "This dataset is intended for testing the common-fetch data loader. \nThe only mandatory parameter is 'year', which determines the dataset to be loaded. \n"

# %%
cfl.dummy_dataset.get_dummy_data(year=2025)
# Out:
# Data server successfully prepared 1 data file(s) for download.
# ...
# Successfully downloaded 1 file(s) (0 were locally cached).
# 'This is the dummy data for 2025.'
